# %% [markdown]
# The Nobel Prize has been among the most prestigious international awards since 1901. Each year, awards are bestowed in chemistry, literature, physics, physiology or medicine, economics, and peace. In addition to the honor, prestige, and substantial prize money, the recipient also gets a gold medal with an image of Alfred Nobel (1833 - 1896), who established the prize.
#
# ![](images/Nobel_Prize.png)
#
# The Nobel Foundation has made a dataset available of all prize winners from the outset of the awards from 1901 to 2023. The dataset used in this project is from the Nobel Prize API and is available in the `nobel.csv` file in the `data` folder.
#
# In this project, you'll get a chance to explore and answer several questions related to this prizewinning data. And we encourage you then to explore further questions that you're interested in!

# %%
# Loading in required libraries
import pandas as pd
import seaborn as sns
import numpy as np

# Start coding here!
nobel=pd.read_csv("data/nobel.csv")
#Index(['year', 'category', 'prize', 'motivation', 'prize_share', 'laureate_id',
#       'laureate_type', 'full_name', 'birth_date', 'birth_city',
#       'birth_country', 'sex', 'organization_name', 'organization_city',
#       'organization_country', 'death_date', 'death_city', 'death_country'])

def get_key_by_value(dict_, val):
  for key, value in dict_.items():
    if val == value:
      return key
  return None

#What is the most commonly awarded gender and birth country?
gender_column = nobel['sex'].value_counts(sort=True)
country_column = nobel['birth_country'].value_counts(sort=True)

top_gender = gender_column.index[0]
top_country = country_column.index[0]

#Which decade had the highest ratio of US-born Nobel Prize winners to total winners in all categories?
#min 1900 - #max 2020
decade_usa={}
for decade in range(1900, 2030, 10):
    decade_usa[decade]=(nobel[(nobel['birth_country']=='United States of America') & (nobel['year']>=decade) & (nobel['year']<decade+10)].shape[0])
max_winners_decade_usa = max(decade_usa.values())    
max_decade_usa = get_key_by_value(decade_usa,max_winners_decade_usa)

#Which decade and Nobel Prize category combination had the highest proportion of female laureates?
#min 1900 - #max 2020
decade_female={}
max_female_dict={}
for decade in range(1900, 2030, 10):
    decade_female[decade]=(nobel[(nobel['year']>=decade) & (nobel['year']<decade+10)][['sex','category']].groupby('category').value_counts(sort=True,normalize=True).reset_index(drop=False).rename(columns={0: 'percentage'}))
    
    
#for i in decade_female:
#    df = decade_female[i]
#    df = df[df['sex']=='Female']
#    print(df)



#for i in decade_female:
    #print(decade_female[i])
#    for x in range(0,len(decade_female[i]),1):
#        print(decade_female[i][x])
    
    #if(decade_female[i]['sex']=='Female'):
        #print('hecho')
        #if(decade_female[i]['percentage']>=acum):
        #    acum=decade_female[i]['percentage']
            #max_female_dict={decade_female[i]['category']:get_key_by_value(decade_female,i)}


        
#print(decade_female)
#########    
#max_decade_female = max(decade_female.values())
#key_decade_female = get_key_by_value(decade_female,max_decade_female)

#categories_max_decade_female = (nobel[(nobel['sex']=='Female') & (nobel['year']>=key_decade_female) & (nobel['year']<=key_decade_female+10)])['category'].value_counts(sort=True)
#max_female_dict = {key_decade_female:categories_max_decade_female.index[0]}  #{2020:'Literature'} #


###########
# Calculating the proportion of female laureates per decade
#nobel['decade'] = (np.floor(nobel['year'] / 10) * 10).astype(int)
#nobel['female_winner'] = nobel['sex'] == 'Female'
#prop_female_winners = nobel.groupby(['decade', 'category'], as_index=False)['female_winner'].mean()

# Find the decade and category with the highest proportion of female laureates
#max_female_decade_category = prop_female_winners[prop_female_winners['female_winner'] == prop_female_winners['female_winner'].max()][['decade', 'category']]

# Create a dictionary with the decade and category pair
#max_female_dict = {max_female_decade_category['decade'].values[0]: max_female_decade_category['category'].values[0]}
###########


#Who was the first woman to receive a Nobel Prize, and in what category?
first_woman = nobel[(nobel['sex']=='Female')].iloc[0]

first_woman_name = first_woman['full_name']
first_woman_category = first_woman['category']

#Which individuals or organizations have won more than one Nobel Prize throughout the years?

no_names_repeat_filter = nobel['full_name']
no_names_repeat_filter = no_names_repeat_filter[no_names_repeat_filter.duplicated(keep=False)].drop_duplicates()
repeat_list = no_names_repeat_filter.to_list()
# Out:
#      category     sex  percentage
# 2  Literature  Female    0.100000
# 5       Peace  Female    0.076923
# 7     Physics  Female    0.076923
#     category     sex  percentage
# 1  Chemistry  Female       0.125
#      category     sex  percentage
# 2  Literature  Female         0.2
#      category     sex  percentage
# 1   Chemistry  Female    0.076923
# 3  Literature  Female    0.111111
# 6       Peace  Female    0.125000
#      category     sex  percentage
# 2  Literature  Female    0.166667
# 4    Medicine  Female    0.071429
# 6       Peace  Female    0.250000
# Empty DataFrame
# Columns: [category, sex, percentage]
# Index: []
#      category     sex  percentage
# 1   Chemistry  Female    0.066667
# 4  Literature  Female    0.090909
# 8     Physics  Female    0.058824
#    category     sex  percentage
# 4  Medicine  Female        0.04
# 6     Peace  Female        0.25
#    category     sex  percentage
# 4  Medicine  Female    0.130435
# 6     Peace  Female    0.125000
# ...
