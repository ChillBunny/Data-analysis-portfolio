# %% [markdown]
# <center><img src="images/redpopcorn.jpg"></center>

# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry.
#
# You work for a production company that specializes in nostalgic styles. You want to do some research on movies released in the 1990's. You'll delve into Netflix data and perform exploratory data analysis to better understand this awesome movie decade!
#
# You have been supplied with the dataset `netflix_data.csv`, along with the following table detailing the column names and descriptions. Feel free to experiment further after submitting!
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv")

# %%
# Start coding here! Use as many cells as you like
release_year_1990 = netflix_df['release_year'] == 1990
duration = int(np.median(netflix_df[release_year_1990]['duration']))
#print(duration)
#print(netflix_df[release_year_1990]['duration'])
#netflix_df['duration'] < 90
short_movie_1990 = np.logical_and(np.logical_and(np.logical_and(np.logical_and(netflix_df['release_year'] < 2000  , netflix_df['release_year'] >= 1990),netflix_df['type'] == 'Movie' ), netflix_df['duration'] < 90),netflix_df['genre'] == 'Action')

short_movie_count = len(netflix_df[short_movie_1990])

#print(netflix_df[short_movie_1990]['genre'])
#print(netflix_df['duration'])
sns.kdeplot(data=netflix_df,x='release_year',y='duration', shade=True,bw_method=0.26,cut=0)
plt.title('Duración de las peliculas en base a su fecha de lanzamiento')
plt.xlabel('Fecha de Lanzamiento')
plt.ylabel('Duración en Minutos')
plt.ylim(0, 200)  # Ajusta el límite superior según tus datos

'''

netflix_df_filtrado = netflix_df[~netflix_df['genre'].isin([])]


custom_palette = sns.color_palette("flare", len(netflix_df_filtrado['genre']))
rainbow_color = custom_palette[-1] 


sns.barplot(data=netflix_df_filtrado['genre'],ci=None,width=0.75,palette=custom_palette)
plt.title('Etiquetas en el Catalogo de Netflix')

plt.ylabel('')

# Obtener el número de barras y la posición de la última barra
num_bars = len(netflix_df_filtrado['genre'])
last_bar_index = num_bars - 1

# Obtener el número de barras
num_bars = len(plt.gca().patches)

# Verificar si hay barras (por si acaso)
if num_bars > 0:
  last_bar_index = num_bars - 1

  # Recorrer las barras y colorear la última (si existe)
  for bar in plt.gca().patches:
      if bar.get_x() + bar.get_width() == plt.gca().patches[last_bar_index].get_x() + plt.gca().patches[last_bar_index].get_width():
          bar.set_facecolor(rainbow_color)
else:
  print("No hay barras en el gráfico")
'''
'''
#sns.scatterplot(data=netflix_df,x='release_year',y='country',size='country',legend=False,sizes=(20,2000)



# Agrupar por año de lanzamiento y género, contando el número de lanzamientos
grouped_df = netflix_df[['release_year', 'genre']]
grouped_df = grouped_df.groupby(['release_year', 'genre']).value_counts().reset_index(name='cantidad_peliculas')



sns.scatterplot(data=grouped_df[grouped_df['release_year']>=1970],x='release_year',y='genre',hue='cantidad_peliculas',size='cantidad_peliculas',palette='hls')
plt.title('Cantidad de Peliculas por año en cada genero en Netflix')
plt.ylabel('')
plt.xlabel('Años de Lanzamiento')
plt.show()
'''
# Out:
# "\n#sns.scatterplot(data=netflix_df,x='release_year',y='country',size='country',legend=False,sizes=(20,2000)\n\n\n\n# Agrupar por año de lanzamiento y género, contando el número de lanzamientos\ngrouped_df = netflix_df[['release_year', 'genre']]\ngrouped_df = grouped_df.groupby(['release_year', 'genre']).value_counts().reset_index(name='cantidad_peliculas')\n\n\n\nsns.scatterplot(data=grouped_df[grouped_df['release_year']>=1970],x='release_year',y='genre',hue='cantidad_peliculas',size='cantidad_peliculas',palette='hls')\nplt.title('Cantidad de Peliculas por año en cada genero en Netflix')\nplt.ylabel('')\nplt.xlabel('Años de Lanzamiento')\nplt.show()\n"
